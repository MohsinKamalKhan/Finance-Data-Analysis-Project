# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime

# %%
start = datetime.datetime(2006, 1, 1)  # year, month, date
end  = datetime.datetime(2016, 1, 1)

# Bank of America
BAC = pd.read_pickle('all_banks.pkl')['BAC']
# CitiGroup
C = pd.read_pickle('all_banks.pkl')['C']
# Goldman Sachs
GS = pd.read_pickle('all_banks.pkl')['GS']
# JPMorgan Chase
JPM = pd.read_pickle('all_banks.pkl')['JPM']
# Morgan Stanley
MS = pd.read_pickle('all_banks.pkl')['MS']
# Wells Forgo
WFC = pd.read_pickle('all_banks.pkl')['WFC']

WFC
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  31.60  31.98  31.20  31.90  11016400
# 2006-01-04  31.80  31.82  31.36  31.53  10871000
# 2006-01-05  31.50  31.56  31.31  31.50  10158000
# 2006-01-06  31.58  31.78  31.38  31.68   8403800
# 2006-01-09  31.68  31.82  31.56  31.68   5619600
# ...           ...    ...    ...    ...       ...
# 2015-12-24  54.97  55.09  54.71  54.82   4999417
# 2015-12-28  54.55  54.78  54.17  54.68   8288841
# 2015-12-29  55.11  55.35  54.99  55.29   7894876
# 2015-12-30  55.27  55.31  54.79  54.89   8016893
# 2015-12-31  54.51  54.95  54.22  54.36  10929767
#
# [2517 rows x 5 columns]

# %%
# Create a list of the ticker symbols (as strings) in alphabetical order.
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
# use pd.concat to concatenate the bank dataframes together in single dataframe
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=tickers)
bank_stocks
# Out:
#               BAC                                      C                  \
# Stock Info   Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04  47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05  46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06  46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09  46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...           ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28  17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29  17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30  17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31  17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
# Set the column name for Banks
bank_stocks.columns.names=['Bank Ticker', 'Stock Info']
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
# What is the max Close price for each bank's stock throughout the time period
for tick in tickers:
    print('Max Closing Pricing for ' + tick + ' bank is ' + str(bank_stocks[tick]['Close'].max()))

# or

bank_stocks.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Max Closing Pricing for BAC bank is 54.9
# Max Closing Pricing for C bank is 564.1
# Max Closing Pricing for GS bank is 247.92
# Max Closing Pricing for JPM bank is 70.08
# Max Closing Pricing for MS bank is 89.3
# Max Closing Pricing for WFC bank is 58.52
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
# Create a new empty DataFrames called returns

returns = pd.DataFrame()

# %%
'''
    use pandas pct_change() method on Close column of each ticker to create column of return values.
'''

for tick in tickers:
    returns[tick + ' Return'] = bank_stocks[tick]['Close'].pct_change()

returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %%
# Create a pairplot using seaborn of the returns dataframe. What stock stands out to you?
import seaborn as sns
sns.pairplot(returns[1:])

# %%
# using returns Dataframe figure out what dates each bank stock had best and worst single day returns
print(returns.idxmin()) # return index of minimum value for each column
print(returns.idxmax()) # return index of maximum value for each column
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
# Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period?

# High standard deviation => a lot of changes (risky)
# Low standard deviation => stability (not risky)

returns.std()
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
# Which would you classify as the riskiest for the year 2015?
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
# Create a distplot using seaborn of 2015 returns of Morgan Stanley

sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='green', bins=50)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4016\3313369379.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], color='green', bins=50)
# <Axes: xlabel='MS Return', ylabel='Density'>

# %%
# Create a distplot using seaborn of 2008 returns for CitiGroup
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='red', bins=50)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4016\525139517.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], color='red', bins=50)
# <Axes: xlabel='C Return', ylabel='Density'>

# %%
# Create a line plot showing Close price for each bank for the entire index of time.
import matplotlib.pyplot as plt
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12, 4))
plt.legend()

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# C:\Users\dell\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.

# %%
# plot the rolling 30 days average against the Close Price for Bank of America's stock for year 2008
plt.figure(figsize=(12, 4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Moving Average')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()

# %%
# Create a heatmap of the correlation between the stocks Close Price
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
# Use seaborn to create clustergroup of correlation
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), annot=True)

# %%
# clustermap using iplot
(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()).iplot(kind='heatmap', colorscale='rdylbu')

# %%
# use .iplot to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016
bac15 = BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
